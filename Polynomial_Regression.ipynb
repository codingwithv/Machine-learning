# %% [markdown]
# <a href="https://colab.research.google.com/github/codingwithv/Machine-learning/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/Position_Salaries.csv")

# %%
dataset.head(3)
# Out:
#    Level  Salary
# 0      1   45000
# 1      2   50000
# 2      3   60000

# %%
dataset.corr()
# Out:
#            Level    Salary
# Level   1.000000  0.817949
# Salary  0.817949  1.000000

# %%
plt.scatter(dataset["Level"],dataset["Salary"])
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %%
x = dataset[["Level"]]
y = dataset[["Salary"]]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=4)
pf.fit(x)
x = pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 97.14666803842445

# %%
# y = m1x1 + m2x2^2 + c
# y = -137634.60994912 * x1 + 20502.04918033] * x2 ^ 2 + 231288.51045789

# %%
lr.coef_
# Out:
# array([[      0.        , -188149.59289   ,   84711.19454691,
#          -13818.79834549,     806.57593376]])

# %%
lr.intercept_
# Out:
# array([162437.01550398])

# %%
prd = lr.predict(x)

# %%
plt.scatter(dataset["Level"],dataset["Salary"])
plt.plot(dataset["Level"], prd, c = 'red')
plt.xlabel("Level")
plt.ylabel("Salary")
plt.legend(["org","prd"])
plt.show()

# %%
test = pf.transform([[3]])
test
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[ 1.,  3.,  9., 27., 81.]])

# %%
lr.predict(test)
# Out:
# array([[52614.08306222]])
